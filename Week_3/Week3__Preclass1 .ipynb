# %%
import pandas as pd
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
import seaborn as sns
from math import floor

# %% [markdown]
# Problem 1:

# %%
data = load_iris()
X = pd.DataFrame(data = data['data'], columns= ['sepal_length', 'sepal_width', 'petal_length', 'petal_width'])
y = pd.DataFrame(data = data['target'], columns= ['Species'])

# %% [markdown]
# Problem 2:

# %%
df = pd.concat([X,y], axis = 1)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  Species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %% [markdown]
# Problem 3:

# %%
df.head(4).info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  4 non-null      float64
#  1   sepal_width   4 non-null      float64
#  2   petal_length  4 non-null      float64
#  3   petal_width   4 non-null      float64
#  4   Species       4 non-null      int64
# dtypes: float64(4), int64(1)
# memory usage: 288.0 bytes

# %%
df.value_counts(['Species'])
# Out:
# Species
# 2          50
# 1          50
# 0          50
# dtype: int64

# %%
isna = df.isnull()
if isna.values.any():
  print('Null value exists!')
else:
  print('Data does not contain null value!')
# Out:
# Data does not contain null value!

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width     Species
# count    150.000000   150.000000    150.000000   150.000000  150.000000
# mean       5.843333     3.057333      3.758000     1.199333    1.000000
# std        0.828066     0.435866      1.765298     0.762238    0.819232
# min        4.300000     2.000000      1.000000     0.100000    0.000000
# 25%        5.100000     2.800000      1.600000     0.300000    0.000000
# 50%        5.800000     3.000000      4.350000     1.300000    1.000000
# 75%        6.400000     3.300000      5.100000     1.800000    2.000000
# max        7.900000     4.400000      6.900000     2.500000    2.000000

# %% [markdown]
# Problem 4:

# %% [markdown]
# It was the American botanist Edgar Anderson who collected the irises and organized the data.
# From the above, it is also called Anderson's dataset.
# Of the three types, two were collected and measured by the same person on the same day, on the same pasture, and on the same device.

# %% [markdown]
# Problem 5:

# %% [markdown]
# Both .loc[] and .iloc[] retrieve data from the Dataframe object.
#
# .loc: retrieve data primarily based on label
#
# .iloc:retrieve data based on index

# %%
sw1 = df.iloc[:,[False,True,False,False,False]]
sw2 = df.loc[:, 'sepal_width']
sw3 = df.iloc[:, 1]
sw1
# Out:
#      sepal_width
# 0            3.5
# 1            3.0
# 2            3.2
# 3            3.1
# 4            3.6
# ..           ...
# 145          3.0
# 146          2.5
# 147          3.0
# 148          3.4
# 149          3.0
#
# [150 rows x 1 columns]

# %%
df.loc[50:99]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  Species
# 50           7.0          3.2           4.7          1.4        1
# 51           6.4          3.2           4.5          1.5        1
# 52           6.9          3.1           4.9          1.5        1
# 53           5.5          2.3           4.0          1.3        1
# 54           6.5          2.8           4.6          1.5        1
# 55           5.7          2.8           4.5          1.3        1
# 56           6.3          3.3           4.7          1.6        1
# 57           4.9          2.4           3.3          1.0        1
# 58           6.6          2.9           4.6          1.3        1
# 59           5.2          2.7           3.9          1.4        1
# 60           5.0          2.0           3.5          1.0        1
# 61           5.9          3.0           4.2          1.5        1
# 62           6.0          2.2           4.0          1.0        1
# ...

# %%
df.loc[50:99, 'petal_length']
# Out:
# 50    4.7
# 51    4.5
# 52    4.9
# 53    4.0
# 54    4.6
# 55    4.5
# 56    4.7
# 57    3.3
# 58    4.6
# 59    3.9
# 60    3.5
# 61    4.2
# 62    4.0
# 63    4.7
# 64    3.6
# 65    4.4
# 66    4.5
# 67    4.1
# 68    4.5
# 69    3.9
# 70    4.8
# 71    4.0
# 72    4.9
# 73    4.7
# 74    4.3
# 75    4.4
# 76    4.8
# 77    5.0
# 78    4.5
# 79    3.5
# 80    3.8
# 81    3.7
# 82    3.9
# 83    5.1
# 84    4.5
# 85    4.5
# 86    4.7
# 87    4.4
# 88    4.1
# 89    4.0
# 90    4.4
# 91    4.6
# 92    4.0
# 93    3.3
# 94    4.2
# 95    4.2
# 96    4.2
# 97    4.3
# 98    3.0
# 99    4.1
# Name: petal_length, dtype: float64

# %%
df.loc[(df['petal_width'] == 0.2)]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  Species
# 0            5.1          3.5           1.4          0.2        0
# 1            4.9          3.0           1.4          0.2        0
# 2            4.7          3.2           1.3          0.2        0
# 3            4.6          3.1           1.5          0.2        0
# 4            5.0          3.6           1.4          0.2        0
# 7            5.0          3.4           1.5          0.2        0
# 8            4.4          2.9           1.4          0.2        0
# 10           5.4          3.7           1.5          0.2        0
# 11           4.8          3.4           1.6          0.2        0
# 14           5.8          4.0           1.2          0.2        0
# 20           5.4          3.4           1.7          0.2        0
# 22           4.6          3.6           1.0          0.2        0
# 24           4.8          3.4           1.9          0.2        0
# ...

# %% [markdown]
# Problem 6:

# %%
plt.title('Pie chart of the number of samples per species')
plt.pie(df['Species'].value_counts(), labels=data['target_names'])
plt.show()

# %% [markdown]
# While a box plot only shows summary statistics such as mean/median and interquartile ranges, the violin plot shows the full distribution of the data.

# %%
fig, ax = plt.subplots(1,1, figsize=(9, 4))
bp1 = ax.boxplot([df.loc[:,'sepal_length'], df.loc[:,'sepal_width'], df.loc[:,'petal_length'], df.loc[:,'petal_width']], vert = True, patch_artist = True, labels = df.columns.values[:4])
colors = ['red', 'green', 'blue', 'pink']

for patch, color in zip(bp1['boxes'], colors):
    patch.set_facecolor(color)

# %%
fig, (ax1, ax2) = plt.subplots(2,2, figsize=(10,8))
vp1 = ax1[0].violinplot(df['sepal_length'],vert = False)
vp2 = ax1[1].violinplot(df['sepal_width'],vert = False)
vp3 = ax2[0].violinplot(df['petal_length'],vert = False)
vp4 = ax2[1].violinplot(df['petal_width'],vert = False)

# %% [markdown]
# Problem 7:

# %%
names = ['sepal_length', 'sepal_width','petal_length','petal_width']
fig, axes = plt.subplots(2, 3, figsize=(12, 8))
pos = 0
for i in names:
  for j in names:
    if i == j: break
    sns.scatterplot(data=df, x=i, y=j, ax=axes[floor(pos/3), pos % 3], hue='Species')
    pos = pos + 1

# %%
pp = sns.pairplot(data=df, hue="Species")

# %%
corr_matrix = df.iloc[:,:-1].corr(method='pearson')
print(corr_matrix)
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
hm = sns.heatmap(data=corr_matrix)

# %% [markdown]
# Problem 8:

# %% [markdown]
# According to the heatmap, there is a strong positive correlation between the petal length and sepal length, petal width and sepal length. There are also medium positive correlation between petal length and petal width.
